# %%
from autograd.tensor import *

# %%
x = Tensor([10,-10,10,-5,6,3,1], requires_grad=True)

# %%
for i in range(100):
    sum_of_squares = tensor_sum(mul(x,x))    
    sum_of_squares.backward()
    print(x.grad)
    
    d_x = mul(Tensor(0.05), x.grad)
    x = Tensor(x.data - d_x.data, requires_grad=True)
    print(i, sum_of_squares)
# Out:
# Tensor([ 20. -20.  20. -10.  12.   6.   2.], requires_grad=False)
# 0 Tensor(371, requires_grad=True)
# Tensor([ 18.  -18.   18.   -9.   10.8   5.4   1.8], requires_grad=False)
# 1 Tensor(300.51000000000005, requires_grad=True)
# Tensor([ 16.2  -16.2   16.2   -8.1    9.72   4.86   1.62], requires_grad=False)
# 2 Tensor(243.4131, requires_grad=True)
# Tensor([ 14.58  -14.58   14.58   -7.29    8.748   4.374   1.458], requires_grad=False)
# 3 Tensor(197.16461099999998, requires_grad=True)
# Tensor([ 13.122  -13.122   13.122   -6.561    7.8732   3.9366   1.3122], requires_grad=False)
# 4 Tensor(159.70333490999994, requires_grad=True)
# Tensor([ 11.8098  -11.8098   11.8098   -5.9049    7.08588   3.54294   1.18098], requires_grad=False)
# 5 Tensor(129.35970127709996, requires_grad=True)
# Tensor([ 10.62882  -10.62882   10.62882   -5.31441    6.377292   3.188646
#    1.062882], requires_grad=False)
# 6 Tensor(104.78135803445099, requires_grad=True)
# Tensor([ 9.565938  -9.565938   9.565938  -4.782969   5.7395628  2.8697814
#   0.9565938], requires_grad=False)
# 7 Tensor(84.8729000079053, requires_grad=True)
# Tensor([ 8.6093442  -8.6093442   8.6093442  -4.3046721   5.16560652  2.58280326
#   0.86093442], requires_grad=False)
# 8 Tensor(68.74704900640329, requires_grad=True)
# Tensor([ 7.74840978 -7.74840978  7.74840978 -3.87420489  4.64904587  2.32452293
#   0.77484098], requires_grad=False)
# 9 Tensor(55.685109695186675, requires_grad=True)
# Tensor([ 6.9735688  -6.9735688   6.9735688  -3.4867844   4.18414128  2.09207064
#   0.69735688], requires_grad=False)
# 10 Tensor(45.10493885310119, requires_grad=True)
# Tensor([ 6.27621192 -6.27621192  6.27621192 -3.13810596  3.76572715  1.88286358
#   0.62762119], requires_grad=False)
# 11 Tensor(36.535000471011976, requires_grad=True)
# Tensor([ 5.64859073 -5.64859073  5.64859073 -2.82429536  3.38915444  1.69457722
#   0.56485907], requires_grad=False)
# 12 Tensor(29.59335038151969, requires_grad=True)
# Tensor([ 5.08373166 -5.08373166  5.08373166 -2.54186583  3.05023899  1.5251195
#   0.50837317], requires_grad=False)
# 13 Tensor(23.970613809030947, requires_grad=True)
# Tensor([ 4.57535849 -4.57535849  4.57535849 -2.28767925  2.74521509  1.37260755
#   0.45753585], requires_grad=False)
# 14 Tensor(19.416197185315063, requires_grad=True)
# Tensor([ 4.11782264 -4.11782264  4.11782264 -2.05891132  2.47069359  1.23534679
#   0.41178226], requires_grad=False)
# 15 Tensor(15.7271197201052, requires_grad=True)
# Tensor([ 3.70604038 -3.70604038  3.70604038 -1.85302019  2.22362423  1.11181211
#   0.37060404], requires_grad=False)
# 16 Tensor(12.738966973285212, requires_grad=True)
# Tensor([ 3.33543634 -3.33543634  3.33543634 -1.66771817  2.0012618   1.0006309
#   0.33354363], requires_grad=False)
# 17 Tensor(10.318563248361023, requires_grad=True)
# Tensor([ 3.00189271 -3.00189271  3.00189271 -1.50094635  1.80113562  0.90056781
#   0.30018927], requires_grad=False)
# 18 Tensor(8.358036231172427, requires_grad=True)
# Tensor([ 2.70170344 -2.70170344  2.70170344 -1.35085172  1.62102206  0.81051103
#   0.27017034], requires_grad=False)
# 19 Tensor(6.770009347249665, requires_grad=True)
# Tensor([ 2.43153309 -2.43153309  2.43153309 -1.21576655  1.45891986  0.72945993
#   0.24315331], requires_grad=False)
# 20 Tensor(5.4837075712722285, requires_grad=True)
# Tensor([ 2.18837978 -2.18837978  2.18837978 -1.09418989  1.31302787  0.65651393
#   0.21883798], requires_grad=False)
# 21 Tensor(4.441803132730504, requires_grad=True)
# Tensor([ 1.9695418  -1.9695418   1.9695418  -0.9847709   1.18172508  0.59086254
#   0.19695418], requires_grad=False)
# 22 Tensor(3.597860537511709, requires_grad=True)
# Tensor([ 1.77258762 -1.77258762  1.77258762 -0.88629381  1.06355257  0.53177629
#   0.17725876], requires_grad=False)
# 23 Tensor(2.9142670353844844, requires_grad=True)
# Tensor([ 1.59532886 -1.59532886  1.59532886 -0.79766443  0.95719732  0.47859866
#   0.15953289], requires_grad=False)
# 24 Tensor(2.3605562986614324, requires_grad=True)
# Tensor([ 1.43579598 -1.43579598  1.43579598 -0.71789799  0.86147759  0.43073879
#   0.1435796 ], requires_grad=False)
# 25 Tensor(1.9120506019157597, requires_grad=True)
# Tensor([ 1.29221638 -1.29221638  1.29221638 -0.64610819  0.77532983  0.38766491
#   0.12922164], requires_grad=False)
# 26 Tensor(1.5487609875517654, requires_grad=True)
# Tensor([ 1.16299474 -1.16299474  1.16299474 -0.58149737  0.69779684  0.34889842
#   0.11629947], requires_grad=False)
# 27 Tensor(1.2544963999169298, requires_grad=True)
# Tensor([ 1.04669527 -1.04669527  1.04669527 -0.52334763  0.62801716  0.31400858
#   0.10466953], requires_grad=False)
# 28 Tensor(1.0161420839327133, requires_grad=True)
# Tensor([ 0.94202574 -0.94202574  0.94202574 -0.47101287  0.56521544  0.28260772
#   0.09420257], requires_grad=False)
# 29 Tensor(0.8230750879854976, requires_grad=True)
# Tensor([ 0.84782317 -0.84782317  0.84782317 -0.42391158  0.5086939   0.25434695
#   0.08478232], requires_grad=False)
# 30 Tensor(0.6666908212682531, requires_grad=True)
# Tensor([ 0.76304085 -0.76304085  0.76304085 -0.38152042  0.45782451  0.22891225
#   0.07630408], requires_grad=False)
# 31 Tensor(0.5400195652272849, requires_grad=True)
# Tensor([ 0.68673676 -0.68673676  0.68673676 -0.34336838  0.41204206  0.20602103
#   0.06867368], requires_grad=False)
# 32 Tensor(0.4374158478341008, requires_grad=True)
# Tensor([ 0.61806309 -0.61806309  0.61806309 -0.30903154  0.37083785  0.18541893
#   0.06180631], requires_grad=False)
# 33 Tensor(0.3543068367456216, requires_grad=True)
# Tensor([ 0.55625678 -0.55625678  0.55625678 -0.27812839  0.33375407  0.16687703
#   0.05562568], requires_grad=False)
# 34 Tensor(0.28698853776395356, requires_grad=True)
# Tensor([ 0.5006311  -0.5006311   0.5006311  -0.25031555  0.30037866  0.15018933
#   0.05006311], requires_grad=False)
# 35 Tensor(0.23246071558880244, requires_grad=True)
# Tensor([ 0.45056799 -0.45056799  0.45056799 -0.225284    0.27034079  0.1351704
#   0.0450568 ], requires_grad=False)
# 36 Tensor(0.18829317962692993, requires_grad=True)
# Tensor([ 0.40551119 -0.40551119  0.40551119 -0.2027556   0.24330672  0.12165336
#   0.04055112], requires_grad=False)
# 37 Tensor(0.15251747549781325, requires_grad=True)
# Tensor([ 0.36496007 -0.36496007  0.36496007 -0.18248004  0.21897604  0.10948802
#   0.03649601], requires_grad=False)
# 38 Tensor(0.12353915515322872, requires_grad=True)
# Tensor([ 0.32846407 -0.32846407  0.32846407 -0.16423203  0.19707844  0.09853922
#   0.03284641], requires_grad=False)
# 39 Tensor(0.10006671567411525, requires_grad=True)
# Tensor([ 0.29561766 -0.29561766  0.29561766 -0.14780883  0.1773706   0.0886853
#   0.02956177], requires_grad=False)
# 40 Tensor(0.08105403969603336, requires_grad=True)
# Tensor([ 0.26605589 -0.26605589  0.26605589 -0.13302795  0.15963354  0.07981677
#   0.02660559], requires_grad=False)
# 41 Tensor(0.06565377215378702, requires_grad=True)
# Tensor([ 0.2394503  -0.2394503   0.2394503  -0.11972515  0.14367018  0.07183509
#   0.02394503], requires_grad=False)
# 42 Tensor(0.05317955544456748, requires_grad=True)
# Tensor([ 0.21550527 -0.21550527  0.21550527 -0.10775264  0.12930316  0.06465158
#   0.02155053], requires_grad=False)
# 43 Tensor(0.043075439910099676, requires_grad=True)
# Tensor([ 0.19395475 -0.19395475  0.19395475 -0.09697737  0.11637285  0.05818642
#   0.01939547], requires_grad=False)
# 44 Tensor(0.034891106327180725, requires_grad=True)
# Tensor([ 0.17455927 -0.17455927  0.17455927 -0.08727964  0.10473556  0.05236778
#   0.01745593], requires_grad=False)
# 45 Tensor(0.02826179612501638, requires_grad=True)
# Tensor([ 0.15710334 -0.15710334  0.15710334 -0.07855167  0.09426201  0.047131
#   0.01571033], requires_grad=False)
# 46 Tensor(0.022892054861263274, requires_grad=True)
# Tensor([ 0.14139301 -0.14139301  0.14139301 -0.0706965   0.08483581  0.0424179
#   0.0141393 ], requires_grad=False)
# 47 Tensor(0.018542564437623248, requires_grad=True)
# Tensor([ 0.12725371 -0.12725371  0.12725371 -0.06362685  0.07635223  0.03817611
#   0.01272537], requires_grad=False)
# 48 Tensor(0.01501947719447483, requires_grad=True)
# Tensor([ 0.11452834 -0.11452834  0.11452834 -0.05726417  0.068717    0.0343585
#   0.01145283], requires_grad=False)
# 49 Tensor(0.01216577652752461, requires_grad=True)
# Tensor([ 0.1030755  -0.1030755   0.1030755  -0.05153775  0.0618453   0.03092265
#   0.01030755], requires_grad=False)
# 50 Tensor(0.009854278987294934, requires_grad=True)
# Tensor([ 0.09276795 -0.09276795  0.09276795 -0.04638398  0.05566077  0.02783039
#   0.0092768 ], requires_grad=False)
# 51 Tensor(0.007981965979708896, requires_grad=True)
# Tensor([ 0.08349116 -0.08349116  0.08349116 -0.04174558  0.0500947   0.02504735
#   0.00834912], requires_grad=False)
# 52 Tensor(0.006465392443564208, requires_grad=True)
# Tensor([ 0.07514204 -0.07514204  0.07514204 -0.03757102  0.04508523  0.02254261
#   0.0075142 ], requires_grad=False)
# 53 Tensor(0.005236967879287008, requires_grad=True)
# Tensor([ 0.06762784 -0.06762784  0.06762784 -0.03381392  0.0405767   0.02028835
#   0.00676278], requires_grad=False)
# 54 Tensor(0.004241943982222476, requires_grad=True)
# Tensor([ 0.06086505 -0.06086505  0.06086505 -0.03043253  0.03651903  0.01825952
#   0.00608651], requires_grad=False)
# 55 Tensor(0.003435974625600206, requires_grad=True)
# Tensor([ 0.05477855 -0.05477855  0.05477855 -0.02738927  0.03286713  0.01643356
#   0.00547785], requires_grad=False)
# 56 Tensor(0.0027831394467361663, requires_grad=True)
# Tensor([ 0.04930069 -0.04930069  0.04930069 -0.02465035  0.02958042  0.01479021
#   0.00493007], requires_grad=False)
# 57 Tensor(0.0022543429518562946, requires_grad=True)
# Tensor([ 0.04437062 -0.04437062  0.04437062 -0.02218531  0.02662237  0.01331119
#   0.00443706], requires_grad=False)
# 58 Tensor(0.0018260177910035987, requires_grad=True)
# Tensor([ 0.03993356 -0.03993356  0.03993356 -0.01996678  0.02396014  0.01198007
#   0.00399336], requires_grad=False)
# 59 Tensor(0.0014790744107129148, requires_grad=True)
# Tensor([ 0.03594021 -0.03594021  0.03594021 -0.0179701   0.02156412  0.01078206
#   0.00359402], requires_grad=False)
# 60 Tensor(0.0011980502726774609, requires_grad=True)
# Tensor([ 0.03234619 -0.03234619  0.03234619 -0.01617309  0.01940771  0.00970386
#   0.00323462], requires_grad=False)
# 61 Tensor(0.0009704207208687437, requires_grad=True)
# Tensor([ 0.02911157 -0.02911157  0.02911157 -0.01455578  0.01746694  0.00873347
#   0.00291116], requires_grad=False)
# 62 Tensor(0.0007860407839036823, requires_grad=True)
# Tensor([ 0.02620041 -0.02620041  0.02620041 -0.01310021  0.01572025  0.00786012
#   0.00262004], requires_grad=False)
# 63 Tensor(0.0006366930349619826, requires_grad=True)
# Tensor([ 0.02358037 -0.02358037  0.02358037 -0.01179018  0.01414822  0.00707411
#   0.00235804], requires_grad=False)
# 64 Tensor(0.0005157213583192058, requires_grad=True)
# Tensor([ 0.02122233 -0.02122233  0.02122233 -0.01061117  0.0127334   0.0063667
#   0.00212223], requires_grad=False)
# 65 Tensor(0.0004177343002385568, requires_grad=True)
# Tensor([ 0.0191001  -0.0191001   0.0191001  -0.00955005  0.01146006  0.00573003
#   0.00191001], requires_grad=False)
# 66 Tensor(0.00033836478319323104, requires_grad=True)
# Tensor([ 0.01719009 -0.01719009  0.01719009 -0.00859504  0.01031405  0.00515703
#   0.00171901], requires_grad=False)
# 67 Tensor(0.00027407547438651714, requires_grad=True)
# Tensor([ 0.01547108 -0.01547108  0.01547108 -0.00773554  0.00928265  0.00464132
#   0.00154711], requires_grad=False)
# 68 Tensor(0.0002220011342530789, requires_grad=True)
# Tensor([ 0.01392397 -0.01392397  0.01392397 -0.00696199  0.00835438  0.00417719
#   0.0013924 ], requires_grad=False)
# 69 Tensor(0.00017982091874499387, requires_grad=True)
# Tensor([ 0.01253157 -0.01253157  0.01253157 -0.00626579  0.00751894  0.00375947
#   0.00125316], requires_grad=False)
# 70 Tensor(0.00014565494418344502, requires_grad=True)
# Tensor([ 0.01127842 -0.01127842  0.01127842 -0.00563921  0.00676705  0.00338353
#   0.00112784], requires_grad=False)
# 71 Tensor(0.00011798050478859048, requires_grad=True)
# Tensor([ 0.01015058 -0.01015058  0.01015058 -0.00507529  0.00609035  0.00304517
#   0.00101506], requires_grad=False)
# 72 Tensor(9.556420887875827e-05, requires_grad=True)
# Tensor([ 0.00913552 -0.00913552  0.00913552 -0.00456776  0.00548131  0.00274066
#   0.00091355], requires_grad=False)
# 73 Tensor(7.740700919179419e-05, requires_grad=True)
# Tensor([ 0.00822197 -0.00822197  0.00822197 -0.00411098  0.00493318  0.00246659
#   0.0008222 ], requires_grad=False)
# 74 Tensor(6.269967744535329e-05, requires_grad=True)
# Tensor([ 0.00739977 -0.00739977  0.00739977 -0.00369988  0.00443986  0.00221993
#   0.00073998], requires_grad=False)
# 75 Tensor(5.078673873073616e-05, requires_grad=True)
# Tensor([ 0.00665979 -0.00665979  0.00665979 -0.0033299   0.00399588  0.00199794
#   0.00066598], requires_grad=False)
# 76 Tensor(4.113725837189629e-05, requires_grad=True)
# Tensor([ 0.00599381 -0.00599381  0.00599381 -0.00299691  0.00359629  0.00179814
#   0.00059938], requires_grad=False)
# 77 Tensor(3.332117928123599e-05, requires_grad=True)
# Tensor([ 0.00539443 -0.00539443  0.00539443 -0.00269722  0.00323666  0.00161833
#   0.00053944], requires_grad=False)
# 78 Tensor(2.6990155217801154e-05, requires_grad=True)
# Tensor([ 0.00485499 -0.00485499  0.00485499 -0.00242749  0.00291299  0.0014565
#   0.0004855 ], requires_grad=False)
# 79 Tensor(2.186202572641894e-05, requires_grad=True)
# Tensor([ 0.00436949 -0.00436949  0.00436949 -0.00218475  0.00262169  0.00131085
#   0.00043695], requires_grad=False)
# 80 Tensor(1.7708240838399337e-05, requires_grad=True)
# Tensor([ 0.00393254 -0.00393254  0.00393254 -0.00196627  0.00235952  0.00117976
#   0.00039325], requires_grad=False)
# 81 Tensor(1.4343675079103466e-05, requires_grad=True)
# Tensor([ 0.00353929 -0.00353929  0.00353929 -0.00176964  0.00212357  0.00106179
#   0.00035393], requires_grad=False)
# 82 Tensor(1.1618376814073806e-05, requires_grad=True)
# Tensor([ 0.00318536 -0.00318536  0.00318536 -0.00159268  0.00191121  0.00095561
#   0.00031854], requires_grad=False)
# 83 Tensor(9.410885219399786e-06, requires_grad=True)
# Tensor([ 0.00286682 -0.00286682  0.00286682 -0.00143341  0.00172009  0.00086005
#   0.00028668], requires_grad=False)
# 84 Tensor(7.622817027713825e-06, requires_grad=True)
# Tensor([ 0.00258014 -0.00258014  0.00258014 -0.00129007  0.00154808  0.00077404
#   0.00025801], requires_grad=False)
# 85 Tensor(6.174481792448197e-06, requires_grad=True)
# Tensor([ 0.00232213 -0.00232213  0.00232213 -0.00116106  0.00139328  0.00069664
#   0.00023221], requires_grad=False)
# 86 Tensor(5.001330251883041e-06, requires_grad=True)
# Tensor([ 0.00208991 -0.00208991  0.00208991 -0.00104496  0.00125395  0.00062697
#   0.00020899], requires_grad=False)
# 87 Tensor(4.051077504025263e-06, requires_grad=True)
# Tensor([ 0.00188092 -0.00188092  0.00188092 -0.00094046  0.00112855  0.00056428
#   0.00018809], requires_grad=False)
# 88 Tensor(3.2813727782604637e-06, requires_grad=True)
# Tensor([ 0.00169283 -0.00169283  0.00169283 -0.00084641  0.0010157   0.00050785
#   0.00016928], requires_grad=False)
# 89 Tensor(2.657911950390975e-06, requires_grad=True)
# Tensor([ 0.00152355 -0.00152355  0.00152355 -0.00076177  0.00091413  0.00045706
#   0.00015235], requires_grad=False)
# 90 Tensor(2.15290867981669e-06, requires_grad=True)
# Tensor([ 0.00137119 -0.00137119  0.00137119 -0.0006856   0.00082272  0.00041136
#   0.00013712], requires_grad=False)
# 91 Tensor(1.743856030651519e-06, requires_grad=True)
# Tensor([ 0.00123407 -0.00123407  0.00123407 -0.00061704  0.00074044  0.00037022
#   0.00012341], requires_grad=False)
# 92 Tensor(1.4125233848277305e-06, requires_grad=True)
# Tensor([ 0.00111067 -0.00111067  0.00111067 -0.00055533  0.0006664   0.0003332
#   0.00011107], requires_grad=False)
# 93 Tensor(1.1441439417104614e-06, requires_grad=True)
# Tensor([ 9.99599161e-04 -9.99599161e-04  9.99599161e-04 -4.99799581e-04
#   5.99759497e-04  2.99879748e-04  9.99599161e-05], requires_grad=False)
# 94 Tensor(9.267565927854736e-07, requires_grad=True)
# Tensor([ 8.99639245e-04 -8.99639245e-04  8.99639245e-04 -4.49819622e-04
#   5.39783547e-04  2.69891773e-04  8.99639245e-05], requires_grad=False)
# 95 Tensor(7.506728401562335e-07, requires_grad=True)
# Tensor([ 8.09675320e-04 -8.09675320e-04  8.09675320e-04 -4.04837660e-04
#   4.85805192e-04  2.42902596e-04  8.09675320e-05], requires_grad=False)
# 96 Tensor(6.080450005265493e-07, requires_grad=True)
# Tensor([ 7.28707788e-04 -7.28707788e-04  7.28707788e-04 -3.64353894e-04
#   4.37224673e-04  2.18612337e-04  7.28707788e-05], requires_grad=False)
# 97 Tensor(4.925164504265049e-07, requires_grad=True)
# Tensor([ 6.55837010e-04 -6.55837010e-04  6.55837010e-04 -3.27918505e-04
#   3.93502206e-04  1.96751103e-04  6.55837010e-05], requires_grad=False)
# 98 Tensor(3.9893832484546885e-07, requires_grad=True)
# Tensor([ 5.90253309e-04 -5.90253309e-04  5.90253309e-04 -2.95126654e-04
#   3.54151985e-04  1.77075993e-04  5.90253309e-05], requires_grad=False)
# 99 Tensor(3.2314004312482986e-07, requires_grad=True)

# %% [markdown]
# # broadcast
# > a.shape -->(3,2)
# > b.shape -->(2,)
#
# a + b means:
# ```py
# for row in a:
#     row + b.view(1,2)
# ```

# %%
import torch
import matplotlib.pyplot as plt

# %%
a = torch.tensor([],requires_grad=True,dtype=torch.float64)

# %%
b = torch.tensor([10.,-10.])

# %%
c = a + b

# %%
c.backward

# %%
b.backward(a)

# %%
a_grad = a.grad

# %%
plt.plot(a.detach(),b.detach())
plt.plot(a.detach(),a_grad,)
plt.legend(['b=2a^2','a_grad'])
plt.show()

# %%
a_grad
