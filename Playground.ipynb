# %%
from autograd.tensor import Tensor

# %%
x = Tensor([10,-10,10,-5,6,3,1], requires_grad=True)

# %%
for i in range(100):
    x.zero_grad()
    sum_of_squares = (x * x).sum()
    sum_of_squares.backward()
    
    d_x = 0.1 * x.grad
    x -= d_x
    print(i, sum_of_squares)
# Out:
# 0 Tensor(371, requires_grad=True)
# 1 Tensor(237.43999999999997, requires_grad=True)
# 2 Tensor(151.96160000000003, requires_grad=True)
# 3 Tensor(97.25542400000002, requires_grad=True)
# 4 Tensor(62.24347136, requires_grad=True)
# 5 Tensor(39.83582167040001, requires_grad=True)
# 6 Tensor(25.494925869056008, requires_grad=True)
# 7 Tensor(16.316752556195844, requires_grad=True)
# 8 Tensor(10.442721635965341, requires_grad=True)
# 9 Tensor(6.683341847017818, requires_grad=True)
# 10 Tensor(4.277338782091404, requires_grad=True)
# 11 Tensor(2.737496820538498, requires_grad=True)
# 12 Tensor(1.7519979651446396, requires_grad=True)
# 13 Tensor(1.121278697692569, requires_grad=True)
# 14 Tensor(0.7176183665232441, requires_grad=True)
# 15 Tensor(0.4592757545748763, requires_grad=True)
# 16 Tensor(0.29393648292792074, requires_grad=True)
# 17 Tensor(0.1881193490738693, requires_grad=True)
# 18 Tensor(0.12039638340727632, requires_grad=True)
# 19 Tensor(0.07705368538065684, requires_grad=True)
# 20 Tensor(0.04931435864362039, requires_grad=True)
# 21 Tensor(0.03156118953191705, requires_grad=True)
# 22 Tensor(0.020199161300426913, requires_grad=True)
# 23 Tensor(0.01292746323227322, requires_grad=True)
# 24 Tensor(0.008273576468654863, requires_grad=True)
# 25 Tensor(0.005295088939939113, requires_grad=True)
# 26 Tensor(0.0033888569215610323, requires_grad=True)
# 27 Tensor(0.0021688684297990605, requires_grad=True)
# 28 Tensor(0.0013880757950713988, requires_grad=True)
# 29 Tensor(0.0008883685088456952, requires_grad=True)
# 30 Tensor(0.000568555845661245, requires_grad=True)
# 31 Tensor(0.0003638757412231969, requires_grad=True)
# 32 Tensor(0.00023288047438284597, requires_grad=True)
# 33 Tensor(0.00014904350360502142, requires_grad=True)
# 34 Tensor(9.538784230721374e-05, requires_grad=True)
# 35 Tensor(6.10482190766168e-05, requires_grad=True)
# 36 Tensor(3.907086020903475e-05, requires_grad=True)
# 37 Tensor(2.500535053378224e-05, requires_grad=True)
# 38 Tensor(1.6003424341620638e-05, requires_grad=True)
# 39 Tensor(1.0242191578637209e-05, requires_grad=True)
# 40 Tensor(6.555002610327811e-06, requires_grad=True)
# 41 Tensor(4.195201670609799e-06, requires_grad=True)
# 42 Tensor(2.6849290691902713e-06, requires_grad=True)
# 43 Tensor(1.7183546042817733e-06, requires_grad=True)
# 44 Tensor(1.099746946740335e-06, requires_grad=True)
# 45 Tensor(7.038380459138145e-07, requires_grad=True)
# 46 Tensor(4.504563493848413e-07, requires_grad=True)
# 47 Tensor(2.882920636062983e-07, requires_grad=True)
# 48 Tensor(1.8450692070803095e-07, requires_grad=True)
# 49 Tensor(1.1808442925313983e-07, requires_grad=True)
# 50 Tensor(7.55740347220095e-08, requires_grad=True)
# 51 Tensor(4.8367382222086065e-08, requires_grad=True)
# 52 Tensor(3.095512462213508e-08, requires_grad=True)
# 53 Tensor(1.9811279758166457e-08, requires_grad=True)
# 54 Tensor(1.2679219045226534e-08, requires_grad=True)
# 55 Tensor(8.11470018894498e-09, requires_grad=True)
# 56 Tensor(5.193408120924786e-09, requires_grad=True)
# 57 Tensor(3.3237811973918642e-09, requires_grad=True)
# 58 Tensor(2.127219966330793e-09, requires_grad=True)
# 59 Tensor(1.3614207784517075e-09, requires_grad=True)
# 60 Tensor(8.713092982090929e-10, requires_grad=True)
# 61 Tensor(5.576379508538196e-10, requires_grad=True)
# 62 Tensor(3.5688828854644455e-10, requires_grad=True)
# 63 Tensor(2.2840850466972446e-10, requires_grad=True)
# 64 Tensor(1.4618144298862367e-10, requires_grad=True)
# 65 Tensor(9.355612351271914e-11, requires_grad=True)
# 66 Tensor(5.987591904814026e-11, requires_grad=True)
# 67 Tensor(3.8320588190809765e-11, requires_grad=True)
# 68 Tensor(2.452517644211825e-11, requires_grad=True)
# 69 Tensor(1.569611292295568e-11, requires_grad=True)
# 70 Tensor(1.0045512270691635e-11, requires_grad=True)
# 71 Tensor(6.429127853242645e-12, requires_grad=True)
# 72 Tensor(4.114641826075294e-12, requires_grad=True)
# 73 Tensor(2.6333707686881876e-12, requires_grad=True)
# 74 Tensor(1.6853572919604402e-12, requires_grad=True)
# 75 Tensor(1.0786286668546819e-12, requires_grad=True)
# 76 Tensor(6.903223467869965e-13, requires_grad=True)
# 77 Tensor(4.418063019436777e-13, requires_grad=True)
# 78 Tensor(2.827560332439537e-13, requires_grad=True)
# 79 Tensor(1.8096386127613037e-13, requires_grad=True)
# 80 Tensor(1.158168712167234e-13, requires_grad=True)
# 81 Tensor(7.412279757870301e-14, requires_grad=True)
# 82 Tensor(4.7438590450369935e-14, requires_grad=True)
# 83 Tensor(3.036069788823675e-14, requires_grad=True)
# 84 Tensor(1.9430846648471522e-14, requires_grad=True)
# 85 Tensor(1.2435741855021777e-14, requires_grad=True)
# 86 Tensor(7.958874787213935e-15, requires_grad=True)
# 87 Tensor(5.09367986381692e-15, requires_grad=True)
# 88 Tensor(3.259955112842828e-15, requires_grad=True)
# 89 Tensor(2.0863712722194095e-15, requires_grad=True)
# 90 Tensor(1.3352776142204223e-15, requires_grad=True)
# 91 Tensor(8.545776731010705e-16, requires_grad=True)
# 92 Tensor(5.469297107846851e-16, requires_grad=True)
# 93 Tensor(3.5003501490219843e-16, requires_grad=True)
# 94 Tensor(2.2402240953740703e-16, requires_grad=True)
# 95 Tensor(1.4337434210394053e-16, requires_grad=True)
# 96 Tensor(9.175957894652194e-17, requires_grad=True)
# 97 Tensor(5.872613052577403e-17, requires_grad=True)
# 98 Tensor(3.7584723536495374e-17, requires_grad=True)
# 99 Tensor(2.4054223063357045e-17, requires_grad=True)
